# %% [markdown]
# # UX Components: Lee Robinson
# - https://github.com/hy-vee/lerna-yarn-workspaces-monorepo
# - @leerob
# - https://medium.com/hy-vee-engineering/creating-a-monorepo-with-lerna-yarn-workspaces-cf163908965d

# %% [markdown]
# ### Intro
# - everybody at a company building
# - ant.design
# - Component Driven development: https://itnext.io/a-guide-to-component-driven-development-cdd-1516f65d8b55
# - component driven development 2019 domyen mshilman

# %% [markdown]
# ## Goals
# - creating consistancy across organization
# - improve overall quality of codebase
# - increase developer effeciency
#
# Composing applications vs Reiventing the Wheel
#
# ### Decision:
# - Build vs open source?
#   - Depends on company size and amount of effort can place towards something
# - Css vs Sass vs CSS in JS?
#   - Recommends the third one for starters
#   - Recommends styled components
#   - https://www.gatsbyjs.org/docs/tailwind-css/
#   - https://dev.to/lpbayliss/how-and-why-i-use-emotion-with-tailwind-4elj

# %% [markdown]
# ### Styled Component Architecture:
# - Designating styles for reusable components:
# - Using props varients
#   - https://blog.bitsrc.io/understanding-react-default-props-5c50401ed37d
#   - https://www.styled-components.com/docs/tooling
#   - https://blog.logrocket.com/a-complete-guide-to-default-props-in-react-984ea8e6972d/
#   - https://reactjs.org/docs/typechecking-with-proptypes.html
#
# ```javascript
# $${(props

# %% [markdown]
# ### Storybook
# - shows UI Components in isolation
# - docs autogenerated
# - testing components to make sure futures don't screw up components
#   - jest with snapshot testing
#   - if you change the styled component - snapshot would tell you what changes
#   - visual testing, not usage testing
# - Can override the docs with custom info
# - Using themes to provide colors and styles depending on what application you're in

# %% [markdown]
# ### Review process:
# - Alpha
#  - [ ] Development
#  - [ ] API
#  - [ ] Design
# - Beta
#  - [x] Development
#  - [ ] API
#  - [ ] Design
# - Prod Ready
#  - [x] Development
#  - [x] API
#  - [x] Design

# %% [markdown]
# ### Using this package (distributed on NPM)
# - Jest, something, and babel
# - yarn build, yarn test, yarn release
# - After it's released - it's good to use?
# - Managing multiple packages with Learna:
#     - With one command, build test and release all at once
#     - Used widely in industry
#     - Single command: lint, build test and release
#     - Easier to coordinate changes across modules
#     - this is the **monorepo**

# %% [markdown]
# ### Deployment Setup:
# - Lerna json file:
#     - packages
#     - npm client
#     - workspaces
# - https://medium.com/hy-vee-engineering/creating-a-monorepo-with-lerna-yarn-workspaces-cf163908965d
# - https://itnext.io/guide-react-app-monorepo-with-lerna-d932afb2e875
# - Conventional commits:
#     - fix: `was broken, no longer broken`
#     - feat: `added new varient prop`
#     - breaking change: `will break usage`

# %% [markdown]
# ### How Developers use this with Best Practice:
# - Startout with a component:
#     - header
#     - footer
#     - link to main area
# - If you make it easy to do the right thing, people will adopt it without you having to tell them to do it
# - Looking at the numbers:
#     - How many repos are using it?
#     - How many file changes are you having?
#     - How does it help?

# %% [markdown]
# ## Questions:
# - If you have a reusable component, and you want this one to have an extra component, how do you do that?
# - Is your styled components used and testing in a separate library, npm package, etc?
#   - Part of CI/CD? How/when is it tested? Who maintains?
#   - How often is the build, test, release process done?
# - Private NPM package or public?
